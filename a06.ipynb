# %% [markdown]
# # Problem Statement
# Download the Iris flower dataset or any other dataset into a DataFrame
#
# Scan the dataset and give the inference as:
#    1.  List down the features and their types (e.g., numeric,nominal) available in the dataset.
#    2.  Create a histogram for each feature in the dataset to illustrate the feature distributions.
#    3.  Create a box plot for each feature in the dataset.
#    4.  Compare distributions and identify outliers.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='white')

# %%
df = pd.read_csv("Iris.csv")
df

#for dataset without column name used below method
# column_names = ['PetalWidthCm','PetalWidthCm','PetalWidthCm','PetalWidthCm','Species']
# df = pd.read_csv("Iris.csv", names=column_names)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
print("Numeric features : SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm")
print("Nominal features : Species")
# Out:
# Numeric features : SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm
# Nominal features : Species

# %%
# Visulatization of feature distributions using histogram
fig,axs = plt.subplots(2,2,figsize=(20,20))

sns.histplot(x='SepalLengthCm',hue='Species',data=df,ax=axs[0][0])
axs[0][0].set_title("Distribution of Sepal Length by Species")

sns.histplot(x='SepalWidthCm',hue='Species',data=df,ax=axs[0][1])
axs[0][1].set_title("Distribution of Sepal Width by Species")

sns.histplot(x='PetalLengthCm',hue='Species',data=df,ax=axs[1][0])
axs[1][0].set_title("Distribution of Petal Length by Species")

sns.histplot(x='PetalWidthCm',hue='Species',data=df,ax=axs[1][1])
axs[1][1].set_title("Distribution of Petal Width by Species")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualization of numeric against nominal using boxplot
# fig,axs = plt.subplots(2,2,figsize=(20,20))
#
# sns.boxplot(x='Species',y='SepalLengthCm',ax=axs[0][0],data=df)
# sns.boxplot(x='Species',y='SepalWidthCm',ax=axs[0][1],data=df)
# sns.boxplot(x='Species',y='PetalLengthCm',ax=axs[1][0],data=df)
# sns.boxplot(x='Species',y='PetalWidthCm',ax=axs[1][1],data=df)
#
# plt.show()
